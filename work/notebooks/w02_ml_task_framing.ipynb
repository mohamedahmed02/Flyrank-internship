# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mohamedahmed02/Flyrank-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

print("""
Task type: Classification

We predict whether a content item is declining or not.
The predicted probability can then be used to rank items
for an editor review queue.
""")
# Out:
# Task type: Classification
#
# We predict whether a content item is declining or not.
# The predicted probability can then be used to rank items
# for an editor review queue.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("""
Target/proxy: is_declining_label

Definition:
is_declining_label = (trend_direction == "down")

This is a proxy label derived from the current performance window,
not an independent future outcome.
""")

# print("Declining proxy rate:", round(df["is_declining_label"].mean() * 100, 2), "%")
# Out:
# Target/proxy: is_declining_label
#
# Definition:
# is_declining_label = (trend_direction == "down")
#
# This is a proxy label derived from the current performance window,
# not an independent future outcome.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
k = 50

print(f"""
Success metric: Precision@{k}

A good result means that a large share of the top {k}
ranked content items are positive under our proxy label.
""")
# Out:
# Success metric: Precision@50
#
# A good result means that a large share of the top 50
# ranked content items are positive under our proxy label.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

path = "/content/content_refresh_anonymized.csv"

df = pd.read_csv(path)

print("Shape:", df.shape)
print("Rows:", len(df))
print("Unique content items:", df["content_id"].nunique())

display(df.head())
# Out:
# Shape: (30000, 44)
# Rows: 30000
# Unique content items: 30000
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("""
A fixed rule can identify obvious declining pages,
but the starter data contains many observable signals at the same time: search volume, impressions, clicks, sessions, position, CTR, content age, freshness, content type, intent, and engagement signals.
Their relationships are not captured well by one simple threshold.
ML can combine these signals and produce a probability that can be used for ranking.
We will only claim decision-support performance, not that a refresh will cause recovery
""")
# Out:
# A fixed rule can identify obvious declining pages,
# but the starter data contains many observable signals at the same time: search volume, impressions, clicks, sessions, position, CTR, content age, freshness, content type, intent, and engagement signals.
# Their relationships are not captured well by one simple threshold.
#  ML can combine these signals and produce a probability that can be used for ranking.
#   We will only claim decision-support performance, not that a refresh will cause recovery

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
