# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mohamedahmed02/Flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

''' Refresh/ contenent opportunity scoring
identify which content pages should be reviewed first for refresh or improvement
The starter dataset contains 30,000 content pages, making manual review impractical.
In addition, 16,262 pages (about 54%) are labeled as "down",
suggesting that a large portion of the content may require attention.
The average content age is 256 days, which also indicates that many pages may benefit from review or updating.


'''
# Out:
# ' Refresh/ contenent opportunity scoring \nidentify which content pages should be reviewed first for refresh or improvement\nThe starter dataset contains 30,000 content pages, making manual review impractical.\nIn addition, 16,262 pages (about 54%) are labeled as "down", \nsuggesting that a large portion of the content may require attention.\nThe average content age is 256 days, which also indicates that many pages may benefit from review or updating.\n\n\n'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

'''
Research Question : Which content pages should be reviewed first to maximize the impact of limited editorial resources?

Decision : Decide which content pages should be reviewed first.

Action: The content team will review the highest-ranked pages first, allowing them to focus on the pages with the greatest potential impact.

Cost of a Wrong Recommendation : If the system recommends low-priority pages, the content team may waste time reviewing less important pages while overlooking pages that require urgent attention. This can reduce the effectiveness of the review process and delay improvements to high-impact content.

Why Machine Learning Can Help:Manually reviewing 30,000 content pages is not practical. Machine learning can analyze multiple signals, such as impressions, content age, CTR, and trend direction, to rank pages according to their priority for review, helping the content team make faster and more informed decisions.


 '''
# Out:
# ' \nResearch Question : Which content pages should be reviewed first to maximize the impact of limited editorial resources?\n\nDecision : Decide which content pages should be reviewed first.\n\nAction: The content team will review the highest-ranked pages first, allowing them to focus on the pages with the greatest potential impact.\n\nCost of a Wrong Recommendation : If the system recommends low-priority pages, the content team may waste time reviewing less important pages while overlooking pages that require urgent attention. This can reduce the effectiveness of the review process and delay improvements to high-impact content.\n\nWhy Machine Learning Can Help:Manually reviewing 30,000 content pages is not practical. Machine learning can analyze multiple signals, such as impressions, content age, CTR, and trend direction, to rank pages according to their priority for review, helping the content team make faster and more informed decisions.\n\n\n '

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
from google.colab import files
# uploaded=files.upload()
import pandas as pd
df=pd.read_csv("content_refresh_anonymized.csv")
df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
# df.shape
df["trend_direction"].value_counts()
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %%
# df.columns
df["impressions_90d"].describe()
# Out:
# count     30000.000000
# mean       5200.366300
# std       16838.019547
# min           1.000000
# 25%          81.000000
# 50%         731.000000
# 75%        3615.250000
# max      517715.000000
# Name: impressions_90d, dtype: float64

# %%
# df.info()
df["content_age_days"].describe()
# Out:
# count    30000.00000
# mean       256.16780
# std        132.70793
# min         90.00000
# 25%        132.00000
# 50%        236.00000
# 75%        333.00000
# max        564.00000
# Name: content_age_days, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.


'''
claim
can rank content pages based on their priority for review.

can't claim
cannot claim that the model predicts Google's search algorithm or future ranking changes.
'''
# Out:
# "\nclaim\ncan rank content pages based on their priority for review.\n\ncan't claim \ncannot claim that the model predicts Google's search algorithm or future ranking changes.\n"

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
